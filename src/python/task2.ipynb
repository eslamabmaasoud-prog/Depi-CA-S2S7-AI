# %%
'''  
Solution to Task 2

'''
# Out:
# '  \nSolution to Task 2\n\n'

# %%
massage = "###!!@emocleW EPGTQ!!!6789"

# %%
print(massage)
# Out:
# ###!!@emocleW EPGTQ!!!6789

# %%
#remove 
text = massage.strip("###!!@!!!6789")
print(text)
# Out:
# emocleW EPGTQ

# %%
#Classification of Speech
textcore = text.split()
print(textcore)
# Out:
# ['emocleW', 'EPGTQ']

# %%
print(textcore[0])
print(textcore[1])
# Out:
# emocleW
# EPGTQ

# %%
#The opposite of the first word
textcore[0]=textcore[0][::-1]
print(textcore)
# Out:
# ['Welcome', 'EPGTQ']

# %%
textcore = ' '.join(textcore)
textcore
# Out:
# 'Welcome EPGTQ'
