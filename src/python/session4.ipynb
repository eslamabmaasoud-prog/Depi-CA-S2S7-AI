# %%
number = 29
is_prime = True
 
if number <= 1:
    is_prime = False
else:
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            is_prime = False
            break
 
if is_prime:
    print(f"The number {number} is prime.")
else:
    print(f"The number {number} is not prime.")
# Out:
# The number 29 is prime.

# %%
def is_prime(number:int,is_prime=True):
        if number <= 1:
            is_prime = False
        else:
            for i in range(2, int(number ** 0.5) + 1):
                if number % i == 0:
                     is_prime = False
                     break
 
        if is_prime:
            print(f"The number {number} is prime.")
        else:
            print(f"The number {number} is not prime.")

# %%
def is_prime(num : int )->bool :
    for i in range(2, num):
        if num % i == 0:
            return False

    return True

# %%
is_prime(17)
# Out:
# True

# %%
 #(5) 5*4*3*2*1=120
def factorial (num :int)->int:
    if  num == 0:
        return 1
    return num * factorial(num -1)

# %%
factorial(5)
# Out:
# 120

# %%
def common_divisors(num1:int , num2:int)-> list[int]:
    limit=min(num1,num2) 
    divisors =[]
    for i in range (1, limit +1):
        if num1 % i == 0 and num2 % i==0:
           divisors.append(i)
    return divisors

# %%
common_divisors(10,20)
# Out:
# [1, 2, 5, 10]

# %%
s ="hello world"
lst = s.split()
new_list = lst[::-1]
print(new_list)
# Out:
# ['world', 'hello']

# %%
def revers_words(text: str)-> list:
    lst = s.split()
    new_list = lst[::-1]
    return new_list

# %%
import random 
characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password =""
for _ in range(5):
      password += random.choice(characters) 
print(password)
# Out:
# 1@N1z

# %%
def generate_pass(length: int)->str:
    characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password =""
    for _ in range(5):
      password += random.choice(characters)

    return password

# %%
generate_pass(5)
# Out:
# 'aPbiR'

# %%
def generate_pass(length: int)->str:
    if length <=0:
        raise ValueError("password lenght must be greater than 0")

    return password

# %%
words = ["welcome", "eslam", "hi", "mohamed", "yas", "welcome", "eslam"]

def remove_duplicates(words):
    unique_words = []

    for word in words:
        if word not in unique_words:
            unique_words.append(word)

    return unique_words

print(remove_duplicates(words))
# Out:
# ['welcome', 'eslam', 'hi', 'mohamed', 'yas']

# %%
numbers=[1,2,3,4,5,6]
squres=[]
for num in numbers:
    squres.append(num**2)
squres
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
squres = [num**2 for num in numbers if num % 2==0]
squres
# Out:
# [4, 16, 36]

# %%
set_1={1,1,1,2,2,2,3}
set_1
# Out:
# {1, 2, 3}

# %%
words = ["welcome", "eslam", "hi", "mohamed", "yas", "welcome", "eslam"]
uniqe_words = set(words)
counts = {word :0 for word in uniqe_words}
for i in uniqe_words:
    for j in words:
        if i== j:
            counts[i] +=1
counts
# Out:
# {'yas': 1, 'welcome': 2, 'mohamed': 1, 'hi': 1, 'eslam': 2}

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
for word in unique_words:
    print (f"{word}:{words.count(word)}")
# Out:
# Hi:2
# Ali:4
# No:3
# Welcome:1

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}


def get_respoons(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])   
def main():
    print("chatbot : how can i help you ?")
    while True:
        user_input = input("user : ").lower()
       response = get_response(user_input)
        print("chatbot",responses)
        if user_input == "goodbye":
            break

# %%
get_respoons("Goodbye!")
# Out:
# "I'm sorry, I didn't understand."

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}
 
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])
 
def main():
    print("chatbot : hi how i can help you!")
    while True:
        user_input = input("User:  ").lower()
        response = get_response(user_input)
        print("chatbot ", response)
       
        if user_input == "goodbye":
            break
main()
# Out:
# chatbot : hi how i can help you!
# chatbot  Hi there!
# chatbot  Could you please rephrase that?
# chatbot  Could you please rephrase that?
# chatbot  Goodbye!
