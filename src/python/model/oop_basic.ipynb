# %%
x=10

# %%
class student:
    def __init__(self,name,age,)-> None:
        self.name=name
        self.age=age
       


    def __str__(self):
        return f"my name is {self.name},my age is {self.age}" 
    def __repr__(self) -> str:

        return f"my name is {self.name},my age is {self.age}"

# %%
s1 = student("eslam", 10)
s1
# Out:
# my name is eslam,my age is 10
