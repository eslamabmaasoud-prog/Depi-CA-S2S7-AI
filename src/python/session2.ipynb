# %%
list_one = [1, 2, 3, 4, 'ML', 'NLP', True, [1, 2, 3, 4, True, [1, 2, 3, 4, 5, True, ['ML', 'DL', 'FG']]]]

# %%
list_one[5]
# Out:
# 'NLP'

# %%
list("eslam")
# Out:
# ['e', 's', 'l', 'a', 'm']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_1=["python","c++","c"]
x = list_1.append("html")
print(list_1)
print(x)
# Out:
# ['python', 'c++', 'c', 'html']
# None

# %%
list_1=["python","c++","c"]
list_1.insert(3,"genai")
print(list_1)
# Out:
# ['python', 'c++', 'c', 'genai']

# %%
list_2 = ["depi","learnig","graf"]
list_3 = ["data","eng","big data"]
list_2 .extend(list_3)
list_2
# Out:
# ['depi', 'learnig', 'graf', 'data', 'eng', 'big data']

# %%
list_2 = ["depi","learnig","graf"]
list_3 = ["data","eng","big data"]
list_4 = list_2 + list_3
print(list_4)
# Out:
# ['depi', 'learnig', 'graf', 'data', 'eng', 'big data']

# %%
list_5 = ["def","add","del"]
list_5.remove("add")
print(list_5)
# Out:
# ['def', 'del']

# %%
list_5 = ["def","add","del"]
x=list_5.pop()
print(list_5)
print(x)
# Out:
# ['def', 'add']
# del

# %%
list_6 = ["depi","learnig","graf"]
new_list = []
pop_lst = list_6.pop()
new_list.append(pop_lst)
print(list_6)
print(new_list)
# Out:
# ['depi', 'learnig']
# ['graf']

# %%
list_6 = ["depi","learnig","graf"]
del list_6[:]
list_6
# Out:
# []

# %%
new_lst = [300,200,100]
sorted(new_lst)
print(new_lst)
# Out:
# [300, 200, 100]

# %%
tup1=("depi","learning","python","Dl")
tup1 [1]
# Out:
# 'learning'

# %%
name =["name","age"]
new_tup =tuple(name)
print(new_tup)
print(type(new_tup))
# Out:
# ('name', 'age')
# <class 'tuple'>

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
set1 ={"depi","learning","depi"}
print(type(set1))
set1
# Out:
# <class 'set'>
# {'depi', 'learning'}

# %%
my_set = {1,2,5,3,4,9}
my_set.add(6)
my_set
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
data1 = {101,102,103,104}
data2 = {103,104,105,106}
print(data1.intersection(data2))
# Out:
# {104, 103}

# %%
num1 = float(input("Enter num1: "))
num2 = float(input("Enter num2: "))

print(f"{num1} + {num2} = {num1 + num2}")
# Out:
# 5.0 + 4.0 = 9.0

# %%
a=200   
b=33
if b > a :
    print("b is greater than a" )
if b==a :
    print("a,b are equal")
if b != a:
    print("b is samller than a")
else:
    print("b is not greater than a")
# Out:
# b is samller than a
