# %%
x=10

# %%
print("hello")
# Out:
# hello

# %%
x=20.2
print(type(x))
# Out:
# <class 'float'>

# %%
name = "eslam"
age = "22"
course_name= "ML"
output = f"my name is {name} my age{age} i take {course_name}"
print(output)
# Out:
# my name is eslam my age22 i take ML

# %%
name ="i love ML"
name[2 : 6 : 1]
# Out:
# 'love'

# %%
name ="i love ml"

# %%
capital =name.upper()
print(capital)
# Out:
# I LOVE ML

# %%
capital.lower()
# Out:
# 'i love ml'

# %%
name.split()
# Out:
# ['i', 'love', 'ml']

# %%
x = name.split()
x
